# %%
from __future__ import print_function, division
# %matplotlib inline
import mdtraj as md
import numpy as np
import matplotlib.pyplot as plt
from parmed import gromacs, amber

# %%
traj = md.load('nvt.xtc', top='nvt.gro')

# %%
traj
# Out:
# <mdtraj.Trajectory with 11 frames, 88812 atoms, 28161 residues, and unitcells at 0x7f1aa592dd90>

# %% [markdown]
# ###Converting the Gromacs trajectory (xtc / trr) to Amber trajectory (nc)

# %%
traj.save_netcdf('nvt.nc', force_overwrite=True)

# %% [markdown]
# ###Conversion of the topology file with ParmEd

# %%
#gromacs.GROMACS_TOPDIR = "/usr/local/gromacs/share/gromacs/top"

# %%
gmx_top = gromacs.GromacsTopologyFile('topol.top')

# %%
gmx_gro = gromacs.GromacsGroFile.parse('nvt.gro')

# %%
gmx_top.box = gmx_gro.box #needed because .prmtop contains box info

# %%
gmx_top.positions = gmx_gro.positions

# %%
#amb_prm = amber.AmberParm.load_from_structure(gmx_top)
amb_prm = amber.ChamberParm.from_structure(gmx_top)
# Out:
# 2.2345
# 2.1245
# 0.0001
# 0.0214476105896
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-99afd04b51fb> in <module>()
#       1 #amb_prm = amber.AmberParm.load_from_structure(gmx_top)
# ----> 2 amb_prm = amber.ChamberParm.from_structure(gmx_top)
#
# /home/chevrot/anaconda/lib/python2.7/site-packages/parmed/amber/_chamberparm.pyc in from_structure(cls, struct)
#     155         inst = struct.copy(cls, split_dihedrals=True)
#     156         inst.update_dihedral_exclusions()
# --> 157         inst._add_missing_13_14()
#     158         del inst.adjusts[:]
#     159         inst.pointers = {}
#
# /home/chevrot/anaconda/lib/python2.7/site-packages/parmed/amber/_amberparm.py in _add_missing_13_14(self)
#    1936                         print(SMALL)
#    1937                         print(pair.type.epsilon)
# -> 1938                         raise TypeError('Cannot translate exceptions')
#    1939                     if (abs(scnb - dihedral.type.scnb) < SMALL and abs(scee - dihedral.type.scee) < SMALL):
#    1940                         continue
#
# TypeError: Cannot translate exceptions
